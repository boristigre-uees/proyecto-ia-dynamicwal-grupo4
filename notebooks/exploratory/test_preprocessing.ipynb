# %%
import sys
import os
project_path = os.path.abspath('../..')
if project_path not in sys.path:
    sys.path.append(project_path)
print("Ruta agregada.")
# Out:
# Ruta agregada.

# %%
from src.data.preprocessing import clean_and_prepare_data

print("Import exitoso!")  # Esta línea te dirá si el import funcionó

df = clean_and_prepare_data('../../data/raw/walmart_sales.csv')

df.head(10)
# Out:
# FUNCIÓN clean_and_prepare_data CARGADA CORRECTAMENTE EN EL ARCHIVO
# Import exitoso!
# === INICIANDO LIMPIEZA DE DATOS ===
# Cargando archivo: ../../data/raw/walmart_sales.csv
# Columnas encontradas: ['transaction_id', 'customer_id', 'product_id', 'product_name', 'category', 'quantity_sold', 'unit_price', 'transaction_date', 'store_id', 'store_location', 'inventory_level', 'reorder_point', 'reorder_quantity', 'supplier_id', 'supplier_lead_time', 'customer_age', 'customer_gender', 'customer_income', 'customer_loyalty_level', 'payment_method', 'promotion_applied', 'promotion_type', 'weather_conditions', 'holiday_indicator', 'weekday', 'stockout_indicator', 'forecasted_demand', 'actual_demand']
# Número de filas: 5000
# Fecha convertida desde columna 'transaction_date'
#
# ¡ÉXITO TOTAL! Datos procesados y guardados en:
# ../../data/processed/walmart_sales_processed.csv
# Filas finales: 5000 | Columnas finales: 33
#    transaction_id  customer_id  product_id product_name     category  \
# ...
